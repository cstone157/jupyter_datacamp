# %% [markdown]
# ## 1. Darwin's bibliography
# <p><img src="https://assets.datacamp.com/production/project_607/img/CharlesDarwin.jpg" alt="Charles Darwin" width="300px"></p>
# <p>Charles Darwin is one of the few universal figures of science. His most renowned work is without a doubt his "<em>On the Origin of Species</em>" published in 1859 which introduced the concept of natural selection. But Darwin wrote many other books on a wide range of topics, including geology, plants or his personal life. In this notebook, we will automatically detect how closely related his books are to each other.</p>
# <p>To this purpose, we will develop the bases of <strong>a content-based book recommendation system</strong>, which will determine which books are close to each other based on how similar the discussed topics are. The methods we will use are commonly used in text- or documents-heavy industries such as legal, tech or customer support to perform some common task such as text classification or handling search engine queries.</p>
# <p>Let's take a look at the books we'll use in our recommendation system.</p>

# %%
# Import library
import glob

# The books files are contained in this folder
folder = "../../data/charles_darwin_books/"

# List all the .txt files and sort them alphabetically
files = glob.glob(folder + "*.txt")
for file in files:
    print(file)
# Out:
# ../../data/charles_darwin_books/FormationVegetableMould.txt
# ../../data/charles_darwin_books/VolcanicIslands.txt
# ../../data/charles_darwin_books/CoralReefs.txt
# ../../data/charles_darwin_books/Autobiography.txt
# ../../data/charles_darwin_books/LifeandLettersVol2.txt
# ../../data/charles_darwin_books/EffectsCrossSelfFertilization.txt
# ../../data/charles_darwin_books/VoyageBeagle.txt
# ../../data/charles_darwin_books/OriginofSpecies.txt
# ../../data/charles_darwin_books/MonographCirripedia.txt
# ../../data/charles_darwin_books/LifeandLettersVol1.txt
# ../../data/charles_darwin_books/DifferentFormsofFlowers.txt
# ../../data/charles_darwin_books/DescentofMan.txt
# ../../data/charles_darwin_books/FoundationsOriginofSpecies.txt
# ../../data/charles_darwin_books/GeologicalObservationsSouthAmerica.txt
# ../../data/charles_darwin_books/VariationPlantsAnimalsDomestication.txt
# ../../data/charles_darwin_books/MonographCirripediaVol2.txt
# ../../data/charles_darwin_books/MovementClimbingPlants.txt
# ../../data/charles_darwin_books/InsectivorousPlants.txt
# ../../data/charles_darwin_books/PowerMovementPlants.txt
# ../../data/charles_darwin_books/ExpressionofEmotionManAnimals.txt

# %% [markdown]
# ## 2. Load the contents of each book into Python
# <p>As a first step, we need to load the content of these books into Python and do some basic pre-processing to facilitate the downstream analyses. We call such a collection of texts <strong>a corpus</strong>. We will also store the titles for these books for future reference and print their respective length to get a gauge for their contents.</p>

# %%
# Import libraries
import re, os

# Initialize the object that will contain the texts and titles
txts = []
titles = []

for n in files:
    # Open each file
    f = open(n, encoding='utf-8-sig')
    # Remove all non-alpha-numeric characters
    data = re.sub('[\W_]+', ' ', f.read())
    
    # Store the texts and titles of the books in two separate lists
    txts.append(data)
    titles.append(os.path.basename(n).replace(".txt", ""))

# Print the length, in characters, of each book
[len(t) for t in txts]
# Out:
# [335920,
#  341447,
#  496068,
#  123231,
#  1010643,
#  913713,
#  1149574,
#  916267,
#  767492,
#  1047518,
#  617088,
#  1776539,
#  523021,
#  797401,
#  1043499,
#  1660866,
#  298319,
#  901406,
#  1093567,
#  624232]

# %% [markdown]
# ## 3. Find "On the Origin of Species"
# <p>For the next parts of this analysis, we will often check the results returned by our method for a given book. For consistency, we will refer to Darwin's most famous book: "<em>On the Origin of Species</em>." Let's find to which index this book is associated.</p>

# %%
# Browse the list containing all the titles
for i in range(len(titles)):
    # Store the index if the title is "OriginofSpecies"
    if titles[i] == "OriginofSpecies":
        ori = i
        break

# Print the stored index
print(ori)
# Out:
# 7

# %% [markdown]
# ## 4. Tokenize the corpus
# <p>As a next step, we need to transform the corpus into a format that is easier to deal with for the downstream analyses. We will tokenize our corpus, i.e., transform each text into a list of the individual words (called tokens) it is made of. To check the output of our process, we will print the first 20 tokens of "<em>On the Origin of Species</em>".</p>

# %%
# Define a list of stop words
stoplist = set('for a of the and to in to be which some is at that we i who whom show via may my our might as well'.split())

# Convert the text to lower case 
txts_lower_case = [t.lower() for t in txts]

# Transform the text into tokens 
txts_split = [t.split(' ') for t in txts_lower_case]

# Remove tokens which are part of the list of stop words
texts = [[word for word in txt if word not in stoplist] for txt in txts_split]

# Print the first 20 tokens for the "On the Origin of Species" book
print(texts[ori][:20])
# Out:
# ['', 'on', 'origin', 'species', 'but', 'with', 'regard', 'material', 'world', 'can', 'least', 'go', 'so', 'far', 'this', 'can', 'perceive', 'events', 'are', 'brought']

# %% [markdown]
# ## 5. Stemming of the tokenized corpus
# <p>If you have read <em>On the Origin of Species</em>, you will have noticed that Charles Darwin can use different words to refer to a similar concept. For example, the concept of selection can be described by words such as <em>selection</em>, <em>selective</em>, <em>select</em> or <em>selects</em>. This will dilute the weight given to this concept in the book and potentially bias the results of the analysis.</p>
# <p>To solve this issue, it is a common practice to use a <strong>stemming process</strong>, which will group together the inflected forms of a word so they can be analysed as a single item: <strong>the stem</strong>. In our <em>On the Origin of Species</em> example, the words related to the concept of selection would be gathered under the <em>select</em> stem.</p>
# <p>As we are analysing 20 full books, the stemming algorithm can take several minutes to run and, in order to make the process faster, we will directly load the final results from a pickle file and review the method used to generate it.</p>

# %%
## I don't want to use the pickle files since they are way to big, so instead I'm going to build them and use them in in this sheet
import pickle

# Load the Porter stemming function from the nltk package
from nltk.stem import PorterStemmer

# Create an instance of a PorterStemmer object
porter = PorterStemmer()

# For each token of each text, we generated its stem 
texts_stem = [[porter.stem(token) for token in text] for text in texts]

# Save to pickle file
#pickle.dump( texts_stem, open( "datasets/texts_stem.p", "wb" ) )

# %%
import pickle

# Load the stemmed tokens list from the pregenerated pickle file
#texts_stem = pickle.load(open('datasets/texts_stem.p', 'rb'))

# Print the 20 first stemmed tokens from the "On the Origin of Species" book
print(texts[ori][:20])
# Out:
# ['', 'on', 'origin', 'species', 'but', 'with', 'regard', 'material', 'world', 'can', 'least', 'go', 'so', 'far', 'this', 'can', 'perceive', 'events', 'are', 'brought']

# %% [markdown]
# ## 6. Building a bag-of-words model
# <p>Now that we have transformed the texts into stemmed tokens, we need to build models that will be useable by downstream algorithms.</p>
# <p>First, we need to will create a universe of all words contained in our corpus of Charles Darwin's books, which we call <em>a dictionary</em>. Then, using the stemmed tokens and the dictionary, we will create <strong>bag-of-words models</strong> (BoW) of each of our texts. The BoW models will represent our books as a list of all uniques tokens they contain associated with their respective number of occurrences. </p>
# <p>To better understand the structure of such a model, we will print the five first elements of one of the "<em>On the Origin of Species</em>" BoW model.</p>

# %%
# !pip install gensim

# Load the functions allowing to create and use dictionaries
from gensim import corpora

# Create a dictionary from the stemmed tokens
dictionary = corpora.Dictionary(texts_stem)

# Create a bag-of-words model for each book, using the previously generated dictionary
bows = [dictionary.doc2bow(text) for text in texts_stem]

# Print the first five elements of the On the Origin of species' BoW model
bows[ori][:5]
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.11/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.11/site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.11/site-packages (from gensim) (6.4.0)
# [(0, 2), (2, 2), (8, 11), (9, 11), (10, 7)]

# %% [markdown]
# ## 7. The most common words of a given book
# <p>The results returned by the bag-of-words model is certainly easy to use for a computer but hard to interpret for a human. It is not straightforward to understand which stemmed tokens are present in a given book from Charles Darwin, and how many occurrences we can find.</p>
# <p>In order to better understand how the model has been generated and visualize its content, we will transform it into a DataFrame and display the 10 most common stems for the book "<em>On the Origin of Species</em>".</p>

# %%
# Import pandas to create and manipulate DataFrames
import pandas as pd

# Convert the BoW model for "On the Origin of Species" into a DataFrame
df_bow_origin = pd.DataFrame()

# Add the column names to the DataFrame
df_bow_origin['index'] = [i[0] for i in bows[ori] if i]
df_bow_origin['occurrences'] = [i[1] for i in bows[ori] if i]

# Add a column containing the token corresponding to the dictionary index
df_bow_origin["token"] = [dictionary[index] for index in df_bow_origin.index]

# Sort the DataFrame by descending number of occurrences and print the first 10 values
df_bow_origin.occurrences.sort_values(ascending = False).head(10)
# Out:
# 1057    2023
# 1478    1558
# 1915    1543
# 1211    1480
# 456     1362
# 1487    1201
# 314     1140
# 973     1137
# 2258    1000
# 2061     962
# Name: occurrences, dtype: int64

# %% [markdown]
# ## 8. Build a tf-idf model
# <p>If it wasn't for the presence of the stem "<em>speci</em>", we would have a hard time to guess this BoW model comes from the <em>On the Origin of Species</em> book. The most recurring words are, apart from few exceptions, very common and unlikely to carry any information peculiar to the given book. We need to use an additional step in order to determine which tokens are the most specific to a book.</p>
# <p>To do so, we will use a <strong>tf-idf model</strong> (term frequency–inverse document frequency). This model defines the importance of each word depending on how frequent it is in this text and how infrequent it is in all the other documents. As a result, a high tf-idf score for a word will indicate that this word is specific to this text.</p>
# <p>After computing those scores, we will print the 10 words most specific to the "<em>On the Origin of Species</em>" book (i.e., the 10 words with the highest tf-idf score).</p>

# %%
# Load the gensim functions that will allow us to generate tf-idf models
from gensim.models import TfidfModel

# Generate the tf-idf model
model = TfidfModel(bows)

# Print the model for "On the Origin of Species"
model[bows[ori]]
# Out:
# [(2, 0.0008878482198272163),
#  (9, 0.0011224775671788822),
#  (10, 0.0022632179817679786),
#  (11, 0.0010162418273610247),
#  (12, 0.0007095728560559348),
#  (14, 0.005142024175900624),
#  (15, 0.0008570040293167707),
#  (17, 0.0009183907367827217),
#  (18, 0.0008878482198272163),
#  (19, 0.004257437136335609),
#  (20, 0.0012245209823769623),
#  (21, 0.00020960530948787898),
#  (22, 0.001189343168874088),
#  (23, 0.0008570040293167707),
#  (24, 0.001189343168874088),
#  (25, 0.0007095728560559348),
#  (27, 0.0002040868303961604),
#  (28, 0.0008878482198272163),
#  (29, 0.002838291424223739),
#  (30, 0.002289270869789665),
#  (31, 0.002571012087950312),
#  (32, 0.009514745350992703),
#  (35, 0.002838291424223739),
#  (36, 0.0032018325805547323),
#  (38, 0.002838291424223739),
#  (42, 0.0035478642802796736),
#  (44, 0.0008570040293167707),
#  (46, 0.0010162418273610247),
#  (47, 0.0017169531523422489),
#  (49, 0.0002040868303961604),
#  (50, 0.002395196062681587),
#  (51, 0.005081209136805123),
#  (52, 0.0005723177174474163),
#  (53, 0.0002040868303961604),
#  (55, 0.001189343168874088),
#  (56, 0.0010204341519808018),
#  (59, 0.002378686337748176),
#  (63, 0.0017169531523422489),
#  (68, 0.0005723177174474163),
#  (73, 0.0006466337090765653),
#  (74, 0.002571012087950312),
#  (80, 0.0008570040293167707),
#  (81, 0.0010162418273610247),
#  (102, 0.00041921061897575796),
#  (103, 0.005999028205217395),
#  (104, 0.0030487254820830744),
#  (107, 0.0005102170759904009),
#  (108, 0.00041921061897575796),
#  (110, 0.0041368627059616865),
#  (111, 0.0010162418273610247),
#  (112, 0.0001020434151980802),
#  (113, 0.004285020146583853),
#  (114, 0.004285020146583853),
#  (115, 0.0002040868303961604),
#  (116, 0.0027579084706411245),
#  (117, 0.0008570040293167707),
#  (118, 0.0015885595448084412),
#  (120, 0.0009699505636148481),
#  (121, 0.0008570040293167707),
#  (123, 0.0001020434151980802),
#  (124, 0.0019399011272296961),
#  (125, 0.0034280161172670826),
#  (126, 0.004757372675496352),
#  (127, 0.0010162418273610247),
#  (128, 0.0003061302455942406),
#  (130, 0.009146176446249222),
#  (132, 0.00020960530948787898),
#  (133, 0.009146176446249222),
#  (135, 0.0001020434151980802),
#  (136, 0.006894771176602811),
#  (137, 0.006097450964166149),
#  (138, 0.0017140080586335413),
#  (140, 0.0006122604911884812),
#  (141, 0.0010162418273610247),
#  (142, 0.0013789542353205622),
#  (145, 0.0035680295066222636),
#  (149, 0.0006288159284636369),
#  (150, 0.0022196205495680407),
#  (151, 0.0027579084706411245),
#  (152, 0.0013789542353205622),
#  (153, 0.0005102170759904009),
#  (154, 0.0035680295066222636),
#  (155, 0.0008570040293167707),
#  (156, 0.0006288159284636369),
#  (157, 0.001189343168874088),
#  (158, 0.0007095728560559348),
#  (159, 0.0015885595448084412),
#  (160, 0.0007095728560559348),
#  (161, 0.0006288159284636369),
#  (162, 0.0041368627059616865),
#  (163, 0.0015885595448084412),
#  (164, 0.0014191457121118696),
#  (165, 0.0006466337090765653),
#  (167, 0.0005723177174474163),
#  (168, 0.0013789542353205622),
#  (169, 0.005081209136805123),
#  (170, 0.0008384212379515159),
#  (171, 0.005142024175900624),
#  (172, 0.005081209136805123),
#  (173, 0.002378686337748176),
#  (174, 0.001189343168874088),
#  (175, 0.0008570040293167707),
#  (176, 0.0004081736607923208),
#  (177, 0.0030487254820830744),
#  (178, 0.007713036263850935),
#  (179, 0.006354238179233765),
#  (180, 0.004765678634425324),
#  (181, 0.0008878482198272163),
#  (182, 0.0013789542353205622),
#  (183, 0.01461968963963548),
#  (184, 0.0002040868303961604),
#  (185, 0.00594671584437044),
#  (186, 0.0001020434151980802),
#  (187, 0.00041921061897575796),
#  (189, 0.0015885595448084412),
#  (190, 0.002378686337748176),
#  (191, 0.0006466337090765653),
#  (192, 0.002571012087950312),
#  (193, 0.005515816941282249),
#  (194, 0.002571012087950312),
#  (195, 0.0006288159284636369),
#  (196, 0.00594671584437044),
#  (197, 0.00041921061897575796),
#  (198, 0.0017756964396544327),
#  (199, 0.0013789542353205622),
#  (201, 0.008273725411923373),
#  (202, 0.001189343168874088),
#  (204, 0.0017756964396544327),
#  (205, 0.00020960530948787898),
#  (206, 0.0008384212379515159),
#  (207, 0.0035680295066222636),
#  (208, 0.004177054182752994),
#  (209, 0.0016165842726914136),
#  (210, 0.00032331685453828267),
#  (212, 0.0004081736607923208),
#  (213, 0.005142024175900624),
#  (215, 0.00020960530948787898),
#  (217, 0.0011446354348948326),
#  (218, 0.0008384212379515159),
#  (219, 0.0006466337090765653),
#  (221, 0.0006466337090765653),
#  (222, 0.00032331685453828267),
#  (223, 0.0012932674181531307),
#  (224, 0.00041921061897575796),
#  (225, 0.00041921061897575796),
#  (227, 0.0003061302455942406),
#  (228, 0.0022632179817679786),
#  (229, 0.002838291424223739),
#  (234, 0.0008570040293167707),
#  (237, 0.0012932674181531307),
#  (238, 0.0019399011272296961),
#  (239, 0.0017756964396544327),
#  (240, 0.0006466337090765653),
#  (241, 0.0006466337090765653),
#  (242, 0.0016165842726914136),
#  (243, 0.0013317723297408244),
#  (244, 0.00032331685453828267),
#  (245, 0.0007143039063865614),
#  (246, 0.00032331685453828267),
#  (249, 0.0009699505636148481),
#  (250, 0.008570040293167706),
#  (251, 0.004285020146583853),
#  (252, 0.002289270869789665),
#  (255, 0.0008878482198272163),
#  (256, 0.005676582848447478),
#  (258, 0.0013317723297408244),
#  (259, 0.0014191457121118696),
#  (260, 0.0008878482198272163),
#  (263, 0.002838291424223739),
#  (264, 0.0007095728560559348),
#  (265, 0.00044392410991360816),
#  (266, 0.0010162418273610247),
#  (267, 0.0019399011272296961),
#  (268, 0.006856032234534165),
#  (270, 0.002838291424223739),
#  (272, 0.0005102170759904009),
#  (273, 0.002861588587237082),
#  (275, 0.002838291424223739),
#  (276, 0.0013317723297408244),
#  (278, 0.0020324836547220494),
#  (279, 0.003107468769395257),
#  (284, 0.012429875077581028),
#  (285, 0.0005102170759904009),
#  (288, 0.0018228783452341705),
#  (290, 0.0014672371664151529),
#  (291, 0.0024490419647539246),
#  (292, 0.0016165842726914136),
#  (293, 0.0008878482198272163),
#  (294, 0.0016768424759030318),
#  (295, 0.0029098516908445445),
#  (299, 0.00044392410991360816),
#  (300, 0.0035513928793088653),
#  (301, 0.001632694643169283),
#  (307, 0.03773354934265669),
#  (309, 0.0009183907367827217),
#  (313, 0.00530625759030017),
#  (314, 0.003645756690468341),
#  (315, 0.0022449551343577644),
#  (318, 0.001530651227971203),
#  (326, 0.002289270869789665),
#  (327, 0.0025865348363062614),
#  (328, 0.0017169531523422489),
#  (329, 0.0020408683039616037),
#  (331, 0.0073471258942617735),
#  (333, 0.009592081028619538),
#  (334, 0.0014191457121118696),
#  (340, 0.001632694643169283),
#  (342, 0.0033536849518060637),
#  (343, 0.002571012087950312),
#  (349, 0.0077596045089187845),
#  (350, 0.0013317723297408244),
#  (351, 0.004257437136335609),
#  (352, 0.0017140080586335413),
#  (354, 0.0010204341519808018),
#  (356, 0.0035680295066222636),
#  (357, 0.004757372675496352),
#  (361, 0.0015885595448084412),
#  (365, 0.002088527091376497),
#  (366, 0.001048026547439395),
#  (376, 0.003645756690468341),
#  (380, 0.0009183907367827217),
#  (383, 0.0006122604911884812),
#  (393, 0.0033674327015366465),
#  (396, 0.003107468769395257),
#  (397, 0.002571012087950312),
#  (402, 0.009285950783025299),
#  (404, 0.0016768424759030318),
#  (409, 0.002088527091376497),
#  (411, 0.007102785758617731),
#  (413, 0.006386155704503412),
#  (416, 0.04027918937788823),
#  (417, 0.008325402182118616),
#  (418, 0.002395196062681587),
#  (419, 0.0018228783452341705),
#  (420, 0.005150859457026747),
#  (422, 0.004064967309444099),
#  (425, 0.0013789542353205622),
#  (426, 0.0008878482198272163),
#  (429, 0.0035680295066222636),
#  (430, 0.0006466337090765653),
#  (436, 0.00020960530948787898),
#  (438, 0.00209605309487879),
#  (440, 0.0022632179817679786),
#  (442, 0.001189343168874088),
#  (443, 0.0006288159284636369),
#  (446, 0.0013265643975750425),
#  (447, 0.004790392125363174),
#  (448, 0.01930859471985947),
#  (450, 0.00594671584437044),
#  (453, 0.003774150298002149),
#  (456, 0.020420509056025975),
#  (457, 0.008354108365505987),
#  (459, 0.021748073263001818),
#  (461, 0.051495196749978545),
#  (464, 0.002088527091376497),
#  (465, 0.0019399011272296961),
#  (466, 0.004401711499245458),
#  (467, 0.0013789542353205622),
#  (468, 0.0029344743328303057),
#  (469, 0.0025865348363062614),
#  (471, 0.0007095728560559348),
#  (479, 0.0035680295066222636),
#  (480, 0.0031440796423181845),
#  (481, 0.00457854173957933),
#  (486, 0.00032331685453828267),
#  (487, 0.002653128795150085),
#  (488, 0.0032331685453828272),
#  (490, 0.0033674327015366465),
#  (492, 0.017140080586335413),
#  (493, 0.0029344743328303057),
#  (494, 0.0027579084706411245),
#  (495, 0.002088527091376497),
#  (496, 0.007113692791527172),
#  (497, 0.0010162418273610247),
#  (498, 0.0015885595448084412),
#  (501, 0.004526435963535957),
#  (502, 0.0006466337090765653),
#  (503, 0.0034694761167347265),
#  (504, 0.0017347380583673632),
#  (507, 0.0018864477853909106),
#  (509, 0.002395196062681587),
#  (514, 0.0030487254820830744),
#  (515, 0.0006466337090765653),
#  (520, 0.003877649777527047),
#  (522, 0.0013265643975750425),
#  (527, 0.0006466337090765653),
#  (528, 0.0008384212379515159),
#  (532, 0.0034339063046844977),
#  (533, 0.010210254528012988),
#  (534, 0.005468635035702511),
#  (535, 0.0006122604911884812),
#  (537, 0.0013317723297408244),
#  (539, 0.0025510853799520046),
#  (541, 0.01784014753311132),
#  (546, 0.015461461195363143),
#  (552, 0.0013317723297408244),
#  (553, 0.03455222213027484),
#  (555, 0.0035478642802796736),
#  (556, 0.016547450823846746),
#  (558, 0.0018228783452341705),
#  (560, 0.0027579084706411245),
#  (564, 0.009851449545930311),
#  (565, 0.10284048351801248),
#  (568, 0.005515816941282249),
#  (570, 0.0016768424759030318),
#  (571, 0.0006122604911884812),
#  (572, 0.0017140080586335413),
#  (574, 0.0008878482198272163),
#  (575, 0.0012932674181531307),
#  (577, 0.004177054182752994),
#  (584, 0.00032331685453828267),
#  (585, 0.001632694643169283),
#  (586, 0.002571012087950312),
#  (597, 0.021633204021993),
#  (599, 0.0005723177174474163),
#  (601, 0.0017347380583673632),
#  (602, 0.0027579084706411245),
#  (605, 0.00594671584437044),
#  (608, 0.01792640505916731),
#  (610, 0.02743852933874767),
#  (612, 0.015243627410415371),
#  (613, 0.00044392410991360816),
#  (614, 0.0062954948919215796),
#  (615, 0.009766330418099378),
#  (618, 0.0014191457121118696),
#  (621, 0.004790392125363174),
#  (624, 0.011542026857753811),
#  (625, 0.0002040868303961604),
#  (626, 0.0006288159284636369),
#  (627, 0.0006466337090765653),
#  (629, 0.0035478642802796736),
#  (630, 0.007990633978444945),
#  (632, 0.0018864477853909106),
#  (633, 0.013789542353205623),
#  (634, 0.0022632179817679786),
#  (639, 0.0010162418273610247),
#  (642, 0.0012932674181531307),
#  (643, 0.0016768424759030318),
#  (644, 0.010162418273610247),
#  (648, 0.0004081736607923208),
#  (649, 0.0014191457121118696),
#  (650, 0.002378686337748176),
#  (651, 0.0017347380583673632),
#  (653, 0.01773932140139837),
#  (654, 0.0019388248887635235),
#  (656, 0.0006122604911884812),
#  (658, 0.006497764594124248),
#  (662, 0.008273725411923373),
#  (664, 0.0016165842726914136),
#  (667, 0.0064036651611094645),
#  (668, 0.016259869237776396),
#  (670, 0.004064967309444099),
#  (671, 0.0018228783452341705),
#  (673, 0.004967009992391544),
#  (675, 0.0009699505636148481),
#  (677, 0.0007095728560559348),
#  (678, 0.004257437136335609),
#  (679, 0.002861588587237082),
#  (684, 0.010162418273610247),
#  (687, 0.0015885595448084412),
#  (689, 0.0017169531523422489),
#  (697, 0.001189343168874088),
#  (701, 0.0005723177174474163),
#  (703, 0.010874036631500909),
#  (704, 0.0035632902612939424),
#  (705, 0.002838291424223739),
#  (710, 0.002088527091376497),
#  (713, 0.002395196062681587),
#  (716, 0.010442635456882485),
#  (719, 0.0035564853999211095),
#  (721, 0.008129934618888198),
#  (722, 0.0032331685453828272),
#  (728, 0.004765678634425324),
#  (730, 0.001632694643169283),
#  (734, 0.0017140080586335413),
#  (737, 0.0021287185681678044),
#  (738, 0.0008570040293167707),
#  (740, 0.0027248690233424265),
#  (741, 0.0013265643975750425),
#  (742, 0.016283076557018644),
#  (747, 0.0035680295066222636),
#  (748, 0.007095728560559347),
#  (749, 0.009224447128727152),
#  (751, 0.0015885595448084412),
#  (752, 0.012576318569272738),
#  (754, 0.001048026547439395),
#  (756, 0.021589346877251534),
#  (759, 0.0016165842726914136),
#  (760, 0.0011224775671788822),
#  (761, 0.011316089908839895),
#  (763, 0.00032331685453828267),
#  (770, 0.01792640505916731),
#  (772, 0.0017140080586335413),
#  (773, 0.00916157363175059),
#  (777, 0.0020324836547220494),
#  (778, 0.007548300596004298),
#  (779, 0.009514745350992703),
#  (784, 0.0025865348363062614),
#  (786, 0.0011446354348948326),
#  (798, 0.0006466337090765653),
#  (804, 0.01285506043975156),
#  (805, 0.05549051373920102),
#  (806, 0.0035478642802796736),
#  (808, 0.0035478642802796736),
#  (810, 0.0005723177174474163),
#  (813, 0.0006466337090765653),
#  (814, 0.001189343168874088),
#  (815, 0.011985950967667419),
#  (816, 0.0008384212379515159),
#  (820, 0.0017140080586335413),
#  (824, 0.0050305274277090955),
#  (829, 0.009114391726170852),
#  (830, 0.005468635035702511),
#  (835, 0.0025152637138545477),
#  (838, 0.009605497741664198),
#  (842, 0.0023469985495558443),
#  (843, 0.004285823438319368),
#  (844, 0.0005723177174474163),
#  (848, 0.0031633458711404854),
#  (851, 0.005723177174474164),
#  (853, 0.0012576318569272739),
#  (855, 0.0017169531523422489),
#  (856, 0.0035513928793088653),
#  (858, 0.00032331685453828267),
#  (861, 0.0014286078127731228),
#  (866, 0.0017140080586335413),
#  (868, 0.006632821987875212),
#  (871, 0.0017756964396544327),
#  (872, 0.0008570040293167707),
#  (873, 0.0019399011272296961),
#  (874, 0.0013789542353205622),
#  (877, 0.007245082479063693),
#  (882, 0.0002040868303961604),
#  (884, 0.0022449551343577644),
#  (886, 0.0052042141751020895),
#  (888, 0.006916975213100006),
#  (889, 0.0011446354348948326),
#  (890, 0.004064967309444099),
#  (891, 0.0013789542353205622),
#  (892, 0.0006466337090765653),
#  (894, 0.005081209136805123),
#  (895, 0.0002040868303961604),
#  (896, 0.04039709400213834),
#  (901, 0.001048026547439395),
#  (904, 0.002571012087950312),
#  (906, 0.002571012087950312),
#  (907, 0.002861588587237082),
#  (908, 0.0031633458711404854),
#  (913, 0.0013317723297408244),
#  (915, 0.0035478642802796736),
#  (917, 0.0031771190896168824),
#  (918, 0.0017756964396544327),
#  (927, 0.0017140080586335413),
#  (930, 0.001048026547439395),
#  (931, 0.003774150298002149),
#  (933, 0.009114391726170852),
#  (934, 0.01591877277090051),
#  (936, 0.0015885595448084412),
#  (940, 0.011119916813659089),
#  (941, 0.0020324836547220494),
#  (943, 0.0022632179817679786),
#  (945, 0.006386155704503412),
#  (946, 0.0005723177174474163),
#  (947, 0.0013789542353205622),
#  (949, 0.014227385583054345),
#  (951, 0.001048026547439395),
#  (952, 0.0034280161172670826),
#  (961, 0.0064036651611094645),
#  (962, 0.018448894257454305),
#  (963, 0.0035680295066222636),
#  (965, 0.0015885595448084412),
#  (968, 0.00041921061897575796),
#  (969, 0.0008878482198272163),
#  (970, 0.004203119108997675),
#  (972, 0.00041921061897575796),
#  (973, 0.0012245209823769623),
#  (975, 0.0017169531523422489),
#  (978, 0.0013317723297408244),
#  (979, 0.003645756690468341),
#  (980, 0.004967009992391544),
#  (982, 0.005999028205217395),
#  (984, 0.0009183907367827217),
#  (986, 0.00044392410991360816),
#  (987, 0.0031771190896168824),
#  (994, 0.005468635035702511),
#  (996, 0.0057710134288769055),
#  (1000, 0.002289270869789665),
#  (1001, 0.0011446354348948326),
#  (1003, 0.0009183907367827217),
#  (1006, 0.0064663370907656545),
#  (1007, 0.0011446354348948326),
#  (1008, 0.0016768424759030318),
#  (1009, 0.007291513380936682),
#  (1010, 0.002838291424223739),
#  (1011, 0.0013789542353205622),
#  (1014, 0.009514745350992703),
#  (1015, 0.006288159284636369),
#  (1016, 0.007112970799842219),
#  (1017, 0.016283076557018644),
#  (1020, 0.0008384212379515159),
#  (1023, 0.0030487254820830744),
#  (1024, 0.0010162418273610247),
#  (1025, 0.016259869237776396),
#  (1026, 0.005676582848447478),
#  (1028, 0.011737897331321223),
#  (1030, 0.005819703381689089),
#  (1033, 0.0024490419647539246),
#  (1034, 0.06173283847686632),
#  (1036, 0.005150859457026747),
#  (1038, 0.0013317723297408244),
#  (1039, 0.0007143039063865614),
#  (1040, 0.0015885595448084412),
#  (1041, 0.0006466337090765653),
#  (1043, 0.009766330418099378),
#  (1047, 0.003571519531932807),
#  (1049, 0.007713036263850935),
#  (1051, 0.018200888506457933),
#  (1052, 0.0006466337090765653),
#  (1054, 0.0018228783452341705),
#  (1056, 0.0006122604911884812),
#  (1057, 0.0064036651611094645),
#  (1061, 0.0018228783452341705),
#  (1063, 0.0034280161172670826),
#  (1071, 0.00561238783589441),
#  (1074, 0.007291513380936682),
#  (1077, 0.004285823438319368),
#  (1081, 0.0029344743328303057),
#  (1083, 0.0027579084706411245),
#  (1084, 0.0027579084706411245),
#  (1086, 0.0015885595448084412),
#  (1088, 0.01773932140139837),
#  (1089, 0.003645756690468341),
#  (1090, 0.004401711499245458),
#  (1091, 0.010301718914053494),
#  (1092, 0.005515816941282249),
#  (1093, 0.0017169531523422489),
#  (1095, 0.0034280161172670826),
#  (1103, 0.008367560046242575),
#  (1104, 0.006707369903612127),
#  (1106, 0.0019388248887635235),
#  (1109, 0.006938952233469453),
#  (1111, 0.0013265643975750425),
#  (1112, 0.0019388248887635235),
#  (1114, 0.01727611106513742),
#  (1117, 0.14617200834752256),
#  (1119, 0.0017140080586335413),
#  (1121, 0.002663544659481649),
#  (1122, 0.0017347380583673632),
#  (1125, 0.0012932674181531307),
#  (1126, 0.004203119108997675),
#  (1135, 0.0013789542353205622),
#  (1137, 0.0032018325805547323),
#  (1138, 0.01189343168874088),
#  (1139, 0.0017140080586335413),
#  (1140, 0.001048026547439395),
#  (1141, 0.0007143039063865614),
#  (1147, 0.0027579084706411245),
#  (1149, 0.00020960530948787898),
#  (1151, 0.01930859471985947),
#  (1153, 0.0017169531523422489),
#  (1156, 0.006354238179233765),
#  (1157, 0.005468635035702511),
#  (1158, 0.004177054182752994),
#  (1159, 0.006938952233469453),
#  (1160, 0.014225941599684438),
#  (1163, 0.0035478642802796736),
#  (1166, 0.00044392410991360816),
#  (1167, 0.004203119108997675),
#  (1168, 0.005150859457026747),
#  (1169, 0.0020324836547220494),
#  (1172, 0.001530651227971203),
#  (1176, 0.004439241099136081),
#  (1178, 0.0011224775671788822),
#  (1179, 0.025747598374989272),
#  (1181, 0.007185588188044761),
#  (1183, 0.0006466337090765653),
#  (1188, 0.001189343168874088),
#  (1189, 0.004757372675496352),
#  (1190, 0.0038798022544593923),
#  (1191, 0.0020324836547220494),
#  (1193, 0.0018864477853909106),
#  (1195, 0.0012576318569272739),
#  (1197, 0.0015885595448084412),
#  (1199, 0.0012576318569272739),
#  (1200, 0.002663544659481649),
#  (1201, 0.0064663370907656545),
#  (1203, 0.006214937538790514),
#  (1204, 0.004285020146583853),
#  (1205, 0.0014191457121118696),
#  (1209, 0.00032331685453828267),
#  (1215, 0.0035564853999211095),
#  (1216, 0.008325402182118616),
#  (1218, 0.0012245209823769623),
#  (1219, 0.03828044524991758),
#  (1220, 0.0035564853999211095),
#  (1221, 0.022597520208607672),
#  (1222, 0.010992773054301611),
#  (1223, 0.01285506043975156),
#  (1224, 0.0017140080586335413),
#  (1226, 0.0019388248887635235),
#  (1227, 0.001632694643169283),
#  (1229, 0.0013789542353205622),
#  (1233, 0.0005102170759904009),
#  (1234, 0.0011446354348948326),
#  (1235, 0.0031633458711404854),
#  (1236, 0.00457854173957933),
#  (1238, 0.0010162418273610247),
#  (1240, 0.0010162418273610247),
#  (1242, 0.0015885595448084412),
#  (1247, 0.0005723177174474163),
#  (1251, 0.0018864477853909106),
#  (1252, 0.0017347380583673632),
#  (1253, 0.002395196062681587),
#  (1256, 0.0018367814735654434),
#  (1258, 0.004439241099136081),
#  (1259, 0.004790392125363174),
#  (1260, 0.0023056584043666685),
#  (1264, 0.0261886652176009),
#  (1266, 0.0009699505636148481),
#  (1269, 0.0054963865271508055),
#  (1272, 0.0008163473215846415),
#  (1274, 0.0022196205495680407),
#  (1276, 0.0017347380583673632),
#  (1277, 0.016650804364237232),
#  (1279, 0.0009699505636148481),
#  (1284, 0.0006466337090765653),
#  (1286, 0.0024490419647539246),
#  (1287, 0.030988931868980895),
#  (1288, 0.0011446354348948326),
#  (1291, 0.0004081736607923208),
#  (1292, 0.00032331685453828267),
#  (1296, 0.002571012087950312),
#  (1300, 0.003877649777527047),
#  (1301, 0.0002040868303961604),
#  (1302, 0.002653128795150085),
#  (1308, 0.0009699505636148481),
#  (1310, 0.09054789405408115),
#  (1313, 0.0017140080586335413),
#  (1315, 0.0011224775671788822),
#  (1318, 0.00540830100549825),
#  (1320, 0.005515816941282249),
#  (1322, 0.0034280161172670826),
#  (1325, 0.0014191457121118696),
#  (1326, 0.0025152637138545477),
#  (1328, 0.004064967309444099),
#  (1330, 0.0008878482198272163),
#  (1332, 0.001632694643169283),
#  (1334, 0.0008878482198272163),
#  (1337, 0.002378686337748176),
#  (1340, 0.0015885595448084412),
#  (1341, 0.001189343168874088),
#  (1342, 0.0015885595448084412),
#  (1343, 0.01270847635846753),
#  (1344, 0.005081209136805123),
#  (1348, 0.021996758537733977),
#  (1349, 0.0012576318569272739),
#  (1350, 0.0008570040293167707),
#  (1351, 0.006894771176602811),
#  (1352, 0.0008384212379515159),
#  (1353, 0.01773932140139837),
#  (1357, 0.0011446354348948326),
#  (1360, 0.0013789542353205622),
#  (1361, 0.002395196062681587),
#  (1363, 0.12769360036819882),
#  (1365, 0.004790392125363174),
#  (1369, 0.0019399011272296961),
#  (1370, 0.0005102170759904009),
#  (1372, 0.0004081736607923208),
#  (1374, 0.009531357268850647),
#  (1375, 0.0004081736607923208),
#  (1376, 0.0020408683039616037),
#  (1382, 0.0005102170759904009),
#  (1383, 0.0012932674181531307),
#  (1384, 0.016547450823846746),
#  (1385, 0.0010162418273610247),
#  (1386, 0.0030487254820830744),
#  (1389, 0.0022632179817679786),
#  (1390, 0.03891760478642431),
#  (1392, 0.004387866853517448),
#  (1394, 0.0014286078127731228),
#  (1399, 0.006097450964166149),
#  (1401, 0.0025152637138545477),
#  (1402, 0.0013317723297408244),
#  (1404, 0.006354238179233765),
#  (1405, 0.0034280161172670826),
#  (1406, 0.0217522813857668),
#  (1409, 0.0020324836547220494),
#  (1411, 0.0022632179817679786),
#  (1412, 0.03018316456625457),
#  (1413, 0.009531357268850647),
#  (1414, 0.0001020434151980802),
#  (1416, 0.002663544659481649),
#  (1418, 0.001189343168874088),
#  (1419, 0.0168124764359907),
#  (1422, 0.011353165696894957),
#  (1424, 0.0023469985495558443),
#  (1425, 0.004526435963535957),
#  (1426, 0.0034339063046844977),
#  (1429, 0.01321114375569332),
#  (1430, 0.0027579084706411245),
#  (1432, 0.018775988396446754),
#  (1434, 0.00591851808148865),
#  (1435, 0.0007143039063865614),
#  (1438, 0.002289270869789665),
#  (1439, 0.0012932674181531307),
#  (1440, 0.056056255628418844),
#  (1441, 0.003645756690468341),
#  (1443, 0.0017169531523422489),
#  (1446, 0.0008163473215846415),
#  (1449, 0.005723177174474164),
#  (1450, 0.002088527091376497),
#  (1451, 0.0006122604911884812),
#  (1455, 0.010346139345225045),
#  (1456, 0.0020324836547220494),
#  (1458, 0.005714431251092491),
#  (1462, 0.0005723177174474163),
#  (1463, 0.0010162418273610247),
#  (1468, 0.0010162418273610247),
#  (1469, 0.003645756690468341),
#  (1473, 0.0021287185681678044),
#  (1475, 0.010346139345225045),
#  (1477, 0.010704088519866792),
#  (1478, 0.0005102170759904009),
#  (1483, 0.0024490419647539246),
#  (1484, 0.004285020146583853),
#  (1485, 0.004790392125363174),
#  (1491, 0.00932240630818577),
#  (1492, 0.0032018325805547323),
#  (1498, 0.0007095728560559348),
#  (1500, 0.0006466337090765653),
#  (1502, 0.0698227615285848),
#  (1504, 0.016259869237776396),
#  (1507, 0.0014191457121118696),
#  (1508, 0.0005723177174474163),
#  (1509, 0.015610602833230566),
#  (1510, 0.00969950563614848),
#  (1512, 0.0035564853999211095),
#  (1516, 0.003774150298002149),
#  (1517, 0.11904604420846032),
#  (1518, 0.011119916813659089),
#  (1520, 0.00457854173957933),
#  (1521, 0.0027579084706411245),
#  (1522, 0.0006466337090765653),
#  (1528, 0.010937270071405021),
#  (1530, 0.0022632179817679786),
#  (1532, 0.0054963865271508055),
#  (1534, 0.007942797724042204),
#  (1536, 0.013163307501290574),
#  (1538, 0.006078553975148489),
#  (1539, 0.0022632179817679786),
#  (1543, 0.0027579084706411245),
#  (1546, 0.004526435963535957),
#  (1548, 0.002395196062681587),
#  (1550, 0.0031771190896168824),
#  (1552, 0.00032331685453828267),
#  (1558, 0.002395196062681587),
#  (1559, 0.0014672371664151529),
#  (1560, 0.0006288159284636369),
#  (1561, 0.0031771190896168824),
#  (1567, 0.0012245209823769623),
#  (1569, 0.002571012087950312),
#  (1571, 0.0006122604911884812),
#  (1572, 0.0035680295066222636),
#  (1573, 0.0013265643975750425),
#  (1577, 0.006789653945303936),
#  (1580, 0.00419210618975758),
#  (1584, 0.002395196062681587),
#  (1589, 0.0008570040293167707),
#  (1590, 0.007185588188044761),
#  (1598, 0.004177054182752994),
#  (1602, 0.0034280161172670826),
#  (1604, 0.0031440796423181845),
#  (1605, 0.0009699505636148481),
#  (1606, 0.002663544659481649),
#  (1607, 0.022063267765128996),
#  (1609, 0.0008384212379515159),
#  (1618, 0.00020960530948787898),
#  (1619, 0.0027579084706411245),
#  (1620, 0.0014191457121118696),
#  (1621, 0.01010229810460994),
#  (1625, 0.006916975213100006),
#  (1626, 0.0027579084706411245),
#  (1630, 0.0009699505636148481),
#  (1632, 0.002663544659481649),
#  (1637, 0.0034339063046844977),
#  (1640, 0.001632694643169283),
#  (1641, 0.01429703590327597),
#  (1642, 0.007185588188044761),
#  (1648, 0.0012576318569272739),
#  (1651, 0.002142911719159684),
#  (1652, 0.00020960530948787898),
#  (1653, 0.00032331685453828267),
#  (1657, 0.01189343168874088),
#  (1658, 0.005240132737196974),
#  (1659, 0.002142911719159684),
#  (1663, 0.00209605309487879),
#  (1664, 0.004177054182752994),
#  (1665, 0.030186839474125357),
#  (1667, 0.0006288159284636369),
#  (1668, 0.0015885595448084412),
#  (1670, 0.001632694643169283),
#  (1671, 0.0005102170759904009),
#  (1675, 0.004285020146583853),
#  (1676, 0.002861588587237082),
#  (1677, 0.004177054182752994),
#  (1681, 0.002088527091376497),
#  (1685, 0.0064036651611094645),
#  (1686, 0.1284326869461242),
#  (1687, 0.016708216731011975),
#  (1692, 0.006894771176602811),
#  (1695, 0.006497764594124248),
#  (1699, 0.0018864477853909106),
#  (1705, 0.0017347380583673632),
#  (1707, 0.001632694643169283),
#  (1708, 0.005999028205217395),
#  (1712, 0.0033536849518060637),
#  (1713, 0.0018228783452341705),
#  (1715, 0.001632694643169283),
#  (1718, 0.10823022836754201),
#  (1721, 0.002088527091376497),
#  (1722, 0.0015885595448084412),
#  (1723, 0.0012576318569272739),
#  (1725, 0.0018367814735654434),
#  (1727, 0.005676582848447478),
#  (1729, 0.004257437136335609),
#  (1731, 0.0002040868303961604),
#  (1732, 0.011178660100971271),
#  (1733, 0.0010162418273610247),
#  (1735, 0.0007095728560559348),
#  (1736, 0.0033536849518060637),
#  (1738, 0.00032331685453828267),
#  (1739, 0.0006466337090765653),
#  (1741, 0.00915708347915866),
#  (1742, 0.049676458348627314),
#  (1746, 0.012772311409006825),
#  (1747, 0.006789653945303936),
#  (1748, 0.003645756690468341),
#  (1751, 0.005449738046684853),
#  (1756, 0.023367942080360363),
#  (1757, 0.0030487254820830744),
#  (1758, 0.11353165696894955),
#  (1759, 0.0009699505636148481),
#  (1760, 0.006288159284636369),
#  (1762, 0.004765678634425324),
#  (1763, 0.0014672371664151529),
#  (1764, 0.002755172210348165),
#  (1765, 0.005150859457026747),
#  (1766, 0.0011446354348948326),
#  (1767, 0.04203119108997675),
#  (1768, 0.0017347380583673632),
#  (1769, 0.00020960530948787898),
#  (1770, 0.0002040868303961604),
#  (1771, 0.0005723177174474163),
#  (1773, 0.0008878482198272163),
#  (1776, 0.004757372675496352),
#  (1777, 0.0018228783452341705),
#  (1778, 0.0022196205495680407),
#  (1780, 0.09557705881371853),
#  (1781, 0.00020960530948787898),
#  (1782, 0.0007095728560559348),
#  (1783, 0.007113692791527172),
#  (1784, 0.0012245209823769623),
#  (1785, 0.0021287185681678044),
#  (1786, 0.0005723177174474163),
#  (1787, 0.0017140080586335413),
#  (1793, 0.0005723177174474163),
#  (1794, 0.016428989846890913),
#  (1795, 0.002088527091376497),
#  (1796, 0.013789542353205623),
#  (1797, 0.0008163473215846415),
#  (1798, 0.015243627410415371),
#  (1800, 0.0018228783452341705),
#  (1802, 0.005999028205217395),
#  (1803, 0.005081209136805123),
#  (1804, 0.0012576318569272739),
#  (1806, 0.0025152637138545477),
#  (1807, 0.0006122604911884812),
#  (1808, 0.002755172210348165),
#  (1809, 0.0030487254820830744),
#  (1810, 0.0014672371664151529),
#  (1813, 0.0030487254820830744),
#  (1815, 0.001048026547439395),
#  (1817, 0.001189343168874088),
#  (1818, 0.04317869375450307),
#  (1819, 0.013255991036069592),
#  (1822, 0.0002040868303961604),
#  (1824, 0.0008878482198272163),
#  (1831, 0.0018228783452341705),
#  (1832, 0.030487254820830742),
#  (1836, 0.002289270869789665),
#  (1838, 0.0006288159284636369),
#  (1839, 0.0008878482198272163),
#  (1843, 0.006894771176602811),
#  (1847, 0.0006466337090765653),
#  (1851, 0.0009699505636148481),
#  (1854, 0.0007095728560559348),
#  (1856, 0.005468635035702511),
#  (1857, 0.0013789542353205622),
#  (1858, 0.008434558088358555),
#  (1862, 0.0011446354348948326),
#  (1863, 0.004790392125363174),
#  (1864, 0.0014191457121118696),
#  (1865, 0.002378686337748176),
#  (1870, 0.0012245209823769623),
#  (1875, 0.0005102170759904009),
#  (1876, 0.0013265643975750425),
#  (1877, 0.005327089318963298),
#  (1883, 0.0035513928793088653),
#  (1884, 0.0018228783452341705),
#  (1885, 0.002289270869789665),
#  (1888, 0.02682947961444851),
#  (1893, 0.008082921363457066),
#  (1897, 0.0012932674181531307),
#  (1898, 0.0062954948919215796),
#  (1903, 0.009224447128727152),
#  (1910, 0.0039825008802697),
#  (1912, 0.00044392410991360816),
#  (1914, 0.0017169531523422489),
#  (1916, 0.0008384212379515159),
#  (1917, 0.0008570040293167707),
#  (1927, 0.00540830100549825),
#  (1929, 0.0011446354348948326),
#  (1933, 0.004883165209049689),
#  (1934, 0.012576318569272738),
#  (1936, 0.0031633458711404854),
#  (1941, 0.014649495627149067),
#  (1943, 0.0020408683039616037),
#  (1944, 0.0007095728560559348),
#  (1949, 0.0007095728560559348),
#  (1954, 0.0008570040293167707),
#  (1956, 0.0008878482198272163),
#  (1957, 0.0018228783452341705),
#  (1963, 0.0011446354348948326),
#  (1966, 0.0013789542353205622),
#  (1967, 0.005173069672612523),
#  (1969, 0.00916157363175059),
#  (1970, 0.007113692791527172),
#  (1973, 0.001048026547439395),
#  (1976, 0.0005723177174474163),
#  (1978, 0.0006288159284636369),
#  (1981, 0.0005102170759904009),
#  (1983, 0.0014191457121118696),
#  (1986, 0.002755172210348165),
#  (1987, 0.0024490419647539246),
#  (1988, 0.0031440796423181845),
#  (1989, 0.004757372675496352),
#  (1997, 0.024853116850186346),
#  (1998, 0.003979693192725128),
#  (2005, 0.006143020236227371),
#  (2006, 0.0027248690233424265),
#  (2011, 0.002395196062681587),
#  (2014, 0.0007143039063865614),
#  (2015, 0.0012932674181531307),
#  (2018, 0.007942797724042204),
#  (2020, 0.002378686337748176),
#  (2022, 0.001189343168874088),
#  (2023, 0.0021287185681678044),
#  (2024, 0.0008384212379515159),
#  (2030, 0.008584765761711244),
#  (2031, 0.0014286078127731228),
#  (2033, 0.001189343168874088),
#  (2035, 0.0032331685453828272),
#  (2040, 0.01612285960129667),
#  (2041, 0.002088527091376497),
#  (2044, 0.0020408683039616037),
#  (2046, 0.0004081736607923208),
#  (2048, 0.00591851808148865),
#  (2049, 0.014227385583054345),
#  (2052, 0.004967009992391544),
#  (2053, 0.013789542353205623),
#  (2061, 0.001632694643169283),
#  (2068, 0.0002040868303961604),
#  (2069, 0.0006122604911884812),
#  (2071, 0.16770480776154367),
#  (2072, 0.012429875077581028),
#  (2075, 0.004765678634425324),
#  (2076, 0.020684313529808433),
#  (2081, 0.0025865348363062614),
#  (2088, 0.009580784250726348),
#  (2089, 0.0004081736607923208),
#  (2092, 0.0022196205495680407),
#  (2094, 0.0020324836547220494),
#  (2097, 0.010284048351801248),
#  (2098, 0.0981072282909074),
#  (2102, 0.0021287185681678044),
#  (2103, 0.010937270071405021),
#  (2104, 0.005999028205217395),
#  (2105, 0.003774150298002149),
#  (2106, 0.0034339063046844977),
#  (2115, 0.0027579084706411245),
#  (2118, 0.008273725411923373),
#  (2120, 0.0036735629471308867),
#  (2121, 0.0008570040293167707),
#  (2127, 0.0019399011272296961),
#  (2129, 0.0027579084706411245),
#  (2130, 0.0010162418273610247),
#  (2131, 0.0011446354348948326),
#  (2132, 0.0013789542353205622),
#  (2133, 0.04063455793876656),
#  (2134, 0.0024490419647539246),
#  ...]

# %% [markdown]
# ## 9. The results of the tf-idf model
# <p>Once again, the format of those results is hard to interpret for a human. Therefore, we will transform it into a more readable version and display the 10 most specific words for the "<em>On the Origin of Species</em>" book.</p>

# %%
# Convert the tf-idf model for "On the Origin of Species" into a DataFrame
df_tfidf = pd.DataFrame()

# Name the columns of the DataFrame id and score
df_tfidf['id'] = [i[0] for i in model[bows[ori]]]
df_tfidf['score'] = [i[1] for i in model[bows[ori]]]

# Add the tokens corresponding to the numerical indices for better readability
df_tfidf['token'] = [dictionary[index] for index in df_tfidf.id]

# Sort the DataFrame by descending tf-idf score and print the first 10 rows.
df_tfidf["score"].sort_values(ascending=False).head(10)
# Out:
# 1282    0.327823
# 3204    0.204162
# 2512    0.197968
# 973     0.167705
# 2700    0.148371
# 544     0.146172
# 807     0.128433
# 663     0.127694
# 4057    0.124547
# 3156    0.121348
# Name: score, dtype: float64

# %% [markdown]
# ## 10. Compute distance between texts
# <p>The results of the tf-idf algorithm now return stemmed tokens which are specific to each book. We can, for example, see that topics such as selection, breeding or domestication are defining "<em>On the Origin of Species</em>" (and yes, in this book, Charles Darwin talks quite a lot about pigeons too). Now that we have a model associating tokens to how specific they are to each book, we can measure how related to books are between each other.</p>
# <p>To this purpose, we will use a measure of similarity called <strong>cosine similarity</strong> and we will visualize the results as a distance matrix, i.e., a matrix showing all pairwise distances between Darwin's books.</p>

# %%
# Load the library allowing similarity computations
from gensim import similarities

# Compute the similarity matrix (pairwise distance between all texts)
sims = similarities.MatrixSimilarity(model[bows])

# Transform the resulting list into a dataframe
sim_df = pd.DataFrame(list(sims))

# Add the titles of the books as columns and index of the dataframe
sim_df.columns = titles
sim_df.index = titles

# Print the resulting matrix
sim_df
# Out:
#                                      FormationVegetableMould  VolcanicIslands  \
# FormationVegetableMould                             1.000000         0.059299
# VolcanicIslands                                     0.059299         1.000000
# CoralReefs                                          0.029445         0.057402
# Autobiography                                       0.041182         0.038630
# LifeandLettersVol2                                  0.023943         0.011930
# EffectsCrossSelfFertilization                       0.032270         0.002183
# VoyageBeagle                                        0.098331         0.138034
# OriginofSpecies                                     0.049519         0.035924
# MonographCirripedia                                 0.019864         0.010054
# LifeandLettersVol1                                  0.028357         0.026517
# DifferentFormsofFlowers                             0.010621         0.002624
# DescentofMan                                        0.027106         0.007885
# FoundationsOriginofSpecies                          0.021468         0.017528
# GeologicalObservationsSouthAmerica                  0.067712         0.372272
# VariationPlantsAnimalsDomestication                 0.032647         0.012210
# MonographCirripediaVol2                             0.023915         0.016404
# MovementClimbingPlants                              0.038823         0.002842
# InsectivorousPlants                                 0.035498         0.008526
# PowerMovementPlants                                 0.039911         0.003787
# ExpressionofEmotionManAnimals                       0.021066         0.005595
#
#                                      CoralReefs  Autobiography  \
# FormationVegetableMould                0.029445       0.041182
# VolcanicIslands                        0.057402       0.038630
# CoralReefs                             1.000000       0.049722
# Autobiography                          0.049722       1.000000
# LifeandLettersVol2                     0.017772       0.220023
# EffectsCrossSelfFertilization          0.001936       0.077006
# VoyageBeagle                           0.267414       0.184288
# OriginofSpecies                        0.039200       0.101199
# MonographCirripedia                    0.006321       0.005854
# LifeandLettersVol1                     0.031211       0.399534
# DifferentFormsofFlowers                0.001980       0.066615
# DescentofMan                           0.009516       0.080789
# FoundationsOriginofSpecies             0.022066       0.058990
# GeologicalObservationsSouthAmerica     0.060744       0.030679
# VariationPlantsAnimalsDomestication    0.011383       0.048989
# MonographCirripediaVol2                0.010497       0.008456
# MovementClimbingPlants                 0.001534       0.022999
# InsectivorousPlants                    0.002284       0.014945
# PowerMovementPlants                    0.002686       0.016059
# ExpressionofEmotionManAnimals          0.005062       0.089345
#
#                                      LifeandLettersVol2  \
# FormationVegetableMould                        0.023943
# VolcanicIslands                                0.011930
# CoralReefs                                     0.017772
# Autobiography                                  0.220023
# LifeandLettersVol2                             1.000000
# EffectsCrossSelfFertilization                  0.046567
# VoyageBeagle                                   0.090674
# OriginofSpecies                                0.097736
# MonographCirripedia                            0.004961
# LifeandLettersVol1                             0.885953
# DifferentFormsofFlowers                        0.046692
# DescentofMan                                   0.080569
# FoundationsOriginofSpecies                     0.054703
# GeologicalObservationsSouthAmerica             0.012241
# VariationPlantsAnimalsDomestication            0.050260
# MonographCirripediaVol2                        0.010570
# MovementClimbingPlants                         0.017673
# InsectivorousPlants                            0.016549
# PowerMovementPlants                            0.012017
# ExpressionofEmotionManAnimals                  0.049333
#
#                                      EffectsCrossSelfFertilization  \
# FormationVegetableMould                                   0.032270
# VolcanicIslands                                           0.002183
# CoralReefs                                                0.001936
# Autobiography                                             0.077006
# LifeandLettersVol2                                        0.046567
# EffectsCrossSelfFertilization                             1.000000
# VoyageBeagle                                              0.017183
# OriginofSpecies                                           0.146700
# MonographCirripedia                                       0.003218
# LifeandLettersVol1                                        0.019609
# DifferentFormsofFlowers                                   0.391788
# DescentofMan                                              0.029997
# FoundationsOriginofSpecies                                0.040248
# GeologicalObservationsSouthAmerica                        0.002247
# VariationPlantsAnimalsDomestication                       0.054458
# MonographCirripediaVol2                                   0.002957
# MovementClimbingPlants                                    0.014939
# InsectivorousPlants                                       0.006763
# PowerMovementPlants                                       0.039520
# ExpressionofEmotionManAnimals                             0.006871
#
#                                      VoyageBeagle  OriginofSpecies  \
# FormationVegetableMould                  0.098331         0.049519
# VolcanicIslands                          0.138034         0.035924
# CoralReefs                               0.267414         0.039200
# Autobiography                            0.184288         0.101199
# LifeandLettersVol2                       0.090674         0.097736
# EffectsCrossSelfFertilization            0.017183         0.146700
# VoyageBeagle                             1.000000         0.165247
# OriginofSpecies                          0.165247         1.000000
# MonographCirripedia                      0.014269         0.031278
# LifeandLettersVol1                       0.172502         0.098353
# DifferentFormsofFlowers                  0.013213         0.129152
# DescentofMan                             0.123902         0.267734
# FoundationsOriginofSpecies               0.089075         0.322736
# GeologicalObservationsSouthAmerica       0.259514         0.052878
# VariationPlantsAnimalsDomestication      0.112421         0.404093
# MonographCirripediaVol2                  0.024734         0.037865
# MovementClimbingPlants                   0.012328         0.008858
# InsectivorousPlants                      0.014758         0.014982
# PowerMovementPlants                      0.023967         0.018170
# ExpressionofEmotionManAnimals            0.099124         0.063242
#
#                                      MonographCirripedia  LifeandLettersVol1  \
# FormationVegetableMould                         0.019864            0.028357
# VolcanicIslands                                 0.010054            0.026517
# CoralReefs                                      0.006321            0.031211
# Autobiography                                   0.005854            0.399534
# LifeandLettersVol2                              0.004961            0.885953
# EffectsCrossSelfFertilization                   0.003218            0.019609
# VoyageBeagle                                    0.014269            0.172502
# OriginofSpecies                                 0.031278            0.098353
# MonographCirripedia                             1.000000            0.005839
# LifeandLettersVol1                              0.005839            1.000000
# DifferentFormsofFlowers                         0.009403            0.016188
# DescentofMan                                    0.053426            0.060040
# FoundationsOriginofSpecies                      0.007650            0.057749
# GeologicalObservationsSouthAmerica              0.009260            0.028691
# VariationPlantsAnimalsDomestication             0.022999            0.054805
# MonographCirripediaVol2                         0.516038            0.012716
# MovementClimbingPlants                          0.012450            0.005533
# InsectivorousPlants                             0.019091            0.006062
# PowerMovementPlants                             0.018565            0.009439
# ExpressionofEmotionManAnimals                   0.016802            0.065391
#
#                                      DifferentFormsofFlowers  DescentofMan  \
# FormationVegetableMould                             0.010621      0.027106
# VolcanicIslands                                     0.002624      0.007885
# CoralReefs                                          0.001980      0.009516
# Autobiography                                       0.066615      0.080789
# LifeandLettersVol2                                  0.046692      0.080569
# EffectsCrossSelfFertilization                       0.391788      0.029997
# VoyageBeagle                                        0.013213      0.123902
# OriginofSpecies                                     0.129152      0.267734
# MonographCirripedia                                 0.009403      0.053426
# LifeandLettersVol1                                  0.016188      0.060040
# DifferentFormsofFlowers                             1.000000      0.072792
# DescentofMan                                        0.072792      1.000000
# FoundationsOriginofSpecies                          0.039993      0.135001
# GeologicalObservationsSouthAmerica                  0.002855      0.009628
# VariationPlantsAnimalsDomestication                 0.049405      0.228437
# MonographCirripediaVol2                             0.005451      0.042937
# MovementClimbingPlants                              0.008165      0.005157
# InsectivorousPlants                                 0.007487      0.009468
# PowerMovementPlants                                 0.018831      0.011267
# ExpressionofEmotionManAnimals                       0.006545      0.148642
#
#                                      FoundationsOriginofSpecies  \
# FormationVegetableMould                                0.021468
# VolcanicIslands                                        0.017528
# CoralReefs                                             0.022066
# Autobiography                                          0.058990
# LifeandLettersVol2                                     0.054703
# EffectsCrossSelfFertilization                          0.040248
# VoyageBeagle                                           0.089075
# OriginofSpecies                                        0.322736
# MonographCirripedia                                    0.007650
# LifeandLettersVol1                                     0.057749
# DifferentFormsofFlowers                                0.039993
# DescentofMan                                           0.135001
# FoundationsOriginofSpecies                             1.000000
# GeologicalObservationsSouthAmerica                     0.027300
# VariationPlantsAnimalsDomestication                    0.196578
# MonographCirripediaVol2                                0.010762
# MovementClimbingPlants                                 0.003971
# InsectivorousPlants                                    0.005995
# PowerMovementPlants                                    0.008712
# ExpressionofEmotionManAnimals                          0.047103
#
#                                      GeologicalObservationsSouthAmerica  \
# FormationVegetableMould                                        0.067712
# VolcanicIslands                                                0.372272
# CoralReefs                                                     0.060744
# Autobiography                                                  0.030679
# LifeandLettersVol2                                             0.012241
# EffectsCrossSelfFertilization                                  0.002247
# VoyageBeagle                                                   0.259514
# OriginofSpecies                                                0.052878
# MonographCirripedia                                            0.009260
# LifeandLettersVol1                                             0.028691
# DifferentFormsofFlowers                                        0.002855
# DescentofMan                                                   0.009628
# FoundationsOriginofSpecies                                     0.027300
# GeologicalObservationsSouthAmerica                             1.000000
# VariationPlantsAnimalsDomestication                            0.013737
# MonographCirripediaVol2                                        0.023486
# MovementClimbingPlants                                         0.002046
# InsectivorousPlants                                            0.006844
# PowerMovementPlants                                            0.003450
# ExpressionofEmotionManAnimals                                  0.005246
#
#                                      VariationPlantsAnimalsDomestication  \
# FormationVegetableMould                                         0.032647
# VolcanicIslands                                                 0.012210
# CoralReefs                                                      0.011383
# Autobiography                                                   0.048989
# LifeandLettersVol2                                              0.050260
# EffectsCrossSelfFertilization                                   0.054458
# VoyageBeagle                                                    0.112421
# OriginofSpecies                                                 0.404093
# MonographCirripedia                                             0.022999
# LifeandLettersVol1                                              0.054805
# DifferentFormsofFlowers                                         0.049405
# DescentofMan                                                    0.228437
# FoundationsOriginofSpecies                                      0.196578
# GeologicalObservationsSouthAmerica                              0.013737
# VariationPlantsAnimalsDomestication                             1.000000
# MonographCirripediaVol2                                         0.029694
# MovementClimbingPlants                                          0.011361
# InsectivorousPlants                                             0.010321
# PowerMovementPlants                                             0.020184
# ExpressionofEmotionManAnimals                                   0.082567
#
#                                      MonographCirripediaVol2  \
# FormationVegetableMould                             0.023915
# VolcanicIslands                                     0.016404
# CoralReefs                                          0.010497
# Autobiography                                       0.008456
# LifeandLettersVol2                                  0.010570
# EffectsCrossSelfFertilization                       0.002957
# VoyageBeagle                                        0.024734
# OriginofSpecies                                     0.037865
# MonographCirripedia                                 0.516038
# LifeandLettersVol1                                  0.012716
# DifferentFormsofFlowers                             0.005451
# DescentofMan                                        0.042937
# FoundationsOriginofSpecies                          0.010762
# GeologicalObservationsSouthAmerica                  0.023486
# VariationPlantsAnimalsDomestication                 0.029694
# MonographCirripediaVol2                             1.000000
# MovementClimbingPlants                              0.006762
# InsectivorousPlants                                 0.019657
# PowerMovementPlants                                 0.022154
# ExpressionofEmotionManAnimals                       0.029644
#
#                                      MovementClimbingPlants  \
# FormationVegetableMould                            0.038823
# VolcanicIslands                                    0.002842
# CoralReefs                                         0.001534
# Autobiography                                      0.022999
# LifeandLettersVol2                                 0.017673
# EffectsCrossSelfFertilization                      0.014939
# VoyageBeagle                                       0.012328
# OriginofSpecies                                    0.008858
# MonographCirripedia                                0.012450
# LifeandLettersVol1                                 0.005533
# DifferentFormsofFlowers                            0.008165
# DescentofMan                                       0.005157
# FoundationsOriginofSpecies                         0.003971
# GeologicalObservationsSouthAmerica                 0.002046
# VariationPlantsAnimalsDomestication                0.011361
# MonographCirripediaVol2                            0.006762
# MovementClimbingPlants                             1.000000
# InsectivorousPlants                                0.249011
# PowerMovementPlants                                0.104310
# ExpressionofEmotionManAnimals                      0.005942
#
#                                      InsectivorousPlants  PowerMovementPlants  \
# FormationVegetableMould                         0.035498             0.039911
# VolcanicIslands                                 0.008526             0.003787
# CoralReefs                                      0.002284             0.002686
# Autobiography                                   0.014945             0.016059
# LifeandLettersVol2                              0.016549             0.012017
# EffectsCrossSelfFertilization                   0.006763             0.039520
# VoyageBeagle                                    0.014758             0.023967
# OriginofSpecies                                 0.014982             0.018170
# MonographCirripedia                             0.019091             0.018565
# LifeandLettersVol1                              0.006062             0.009439
# DifferentFormsofFlowers                         0.007487             0.018831
# DescentofMan                                    0.009468             0.011267
# FoundationsOriginofSpecies                      0.005995             0.008712
# GeologicalObservationsSouthAmerica              0.006844             0.003450
# VariationPlantsAnimalsDomestication             0.010321             0.020184
# MonographCirripediaVol2                         0.019657             0.022154
# MovementClimbingPlants                          0.249011             0.104310
# InsectivorousPlants                             1.000000             0.022841
# PowerMovementPlants                             0.022841             1.000000
# ExpressionofEmotionManAnimals                   0.011461             0.011234
#
#                                      ExpressionofEmotionManAnimals
# FormationVegetableMould                                   0.021066
# VolcanicIslands                                           0.005595
# CoralReefs                                                0.005062
# Autobiography                                             0.089345
# LifeandLettersVol2                                        0.049333
# EffectsCrossSelfFertilization                             0.006871
# VoyageBeagle                                              0.099124
# OriginofSpecies                                           0.063242
# MonographCirripedia                                       0.016802
# LifeandLettersVol1                                        0.065391
# DifferentFormsofFlowers                                   0.006545
# DescentofMan                                              0.148642
# FoundationsOriginofSpecies                                0.047103
# GeologicalObservationsSouthAmerica                        0.005246
# VariationPlantsAnimalsDomestication                       0.082567
# MonographCirripediaVol2                                   0.029644
# MovementClimbingPlants                                    0.005942
# InsectivorousPlants                                       0.011461
# PowerMovementPlants                                       0.011234
# ExpressionofEmotionManAnimals                             1.000000

# %% [markdown]
# ## 11. The book most similar to "On the Origin of Species"
# <p>We now have a matrix containing all the similarity measures between any pair of books from Charles Darwin! We can now use this matrix to quickly extract the information we need, i.e., the distance between one book and one or several others. </p>
# <p>As a first step, we will display which books are the most similar to "<em>On the Origin of Species</em>," more specifically we will produce a bar chart showing all books ranked by how similar they are to Darwin's landmark work.</p>

# %%
# This is needed to display plots in a notebook
# %matplotlib inline

# Import libraries
import matplotlib.pyplot as plt

# Select the column corresponding to "On the Origin of Species" and 
v = sim_df.OriginofSpecies

# Sort by ascending scores
v_sorted = v.sort_values()

# Plot this data has a horizontal bar plot
v_sorted.plot.barh()

# Modify the axes labels and plot title for a better readability
plt.xlabel("Similarity")
# Out:
# Text(0.5, 0, 'Similarity')

# %% [markdown]
# ## 12. Which books have similar content?
# <p>This turns out to be extremely useful if we want to determine a given book's most similar work. For example, we have just seen that if you enjoyed "<em>On the Origin of Species</em>," you can read books discussing similar concepts such as "<em>The Variation of Animals and Plants under Domestication</em>" or "<em>The Descent of Man, and Selection in Relation to Sex</em>." If you are familiar with Darwin's work, these suggestions will likely seem natural to you. Indeed, <em>On the Origin of Species</em> has a whole chapter about domestication and <em>The Descent of Man, and Selection in Relation to Sex</em> applies the theory of natural selection to human evolution. Hence, the results make sense.</p>
# <p>However, we now want to have a better understanding of the big picture and see how Darwin's books are generally related to each other (in terms of topics discussed). To this purpose, we will represent the whole similarity matrix as a dendrogram, which is a standard tool to display such data. <strong>This last approach will display all the information about book similarities at once.</strong> For example, we can find a book's closest relative but, also, we can visualize which groups of books have similar topics (e.g., the cluster about Charles Darwin personal life with his autobiography and letters). If you are familiar with Darwin's bibliography, the results should not surprise you too much, which indicates the method gives good results. Otherwise, next time you read one of the author's book, you will know which other books to read next in order to learn more about the topics it addressed.</p>

# %%
# Import libraries
from scipy.cluster import hierarchy

# Compute the clusters from the similarity matrix,
# using the Ward variance minimization algorithm
Z = hierarchy.linkage(sim_df, 'ward')

# Display this result as a horizontal dendrogram
a = hierarchy.dendrogram(Z, leaf_font_size=8, 
                         labels=sim_df.index, orientation="left")
